# %%
import mysql.connector as conn

# %%
mydb=conn.connect(host='localhost',user='root',passwd='himanshu@123')

# %%
cursor=mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.execute("use students")

# %%
cursor.execute("show tables")

# %%
cursor.fetchall()
# Out:
# [('glassdata',)]

# %%
cursor.execute("select *from students.glassdata")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
cursor.execute("select col1,col5,col10 from students.glassdata")

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("select *from students.glassdata where col1 = 3 and col11 = 1")

# %%
cursor.fetchall()
# Out:
# [(3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1)]

# %%
cursor.execute("select *from students.glassdata")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
cursor.execute("UPDATE students.glassdata SET col1=6,col2=8 where col1=1")

# %%
mydb.commit()

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("select *from students.glassdata")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
cursor.execute("select * from students.glassdata where col1=6")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1)]

# %%
cursor.execute("select col1,count(col1),col11 from students.glassdata group by col4")

# %%
cursor.fetchall()
# Out:
# [(6, 3, 1),
#  (2, 6, 1),
#  (3, 6, 1),
#  (5, 10, 1),
#  (6, 8, 1),
#  (9, 16, 1),
#  (11, 2, 1),
#  (12, 8, 1),
#  (13, 6, 1),
#  (14, 8, 1),
#  (15, 6, 1),
#  (16, 16, 1),
#  (17, 6, 1),
#  (18, 4, 1),
#  (19, 2, 1),
#  (22, 2, 1),
#  (24, 8, 1),
#  (25, 8, 1),
#  (27, 16, 1),
#  (29, 14, 1),
#  (30, 6, 1),
#  (34, 6, 1),
#  (36, 6, 1),
#  (37, 4, 1),
#  (39, 4, 1),
#  (42, 2, 1),
#  (43, 4, 1),
#  (44, 2, 1),
#  (47, 2, 1),
#  (48, 2, 1),
#  (49, 2, 1),
#  (50, 2, 1),
#  (51, 2, 1),
#  (52, 4, 1),
#  (53, 2, 1),
#  (54, 2, 1),
#  (55, 2, 1),
#  (56, 2, 1),
#  (59, 6, 1),
#  (63, 2, 1),
#  (64, 2, 1),
#  (67, 6, 1),
#  (72, 2, 2),
#  (85, 2, 2),
#  (92, 2, 2),
#  (93, 4, 2),
#  (94, 6, 2),
#  (98, 2, 2),
#  (99, 2, 2),
#  (100, 2, 2),
#  (101, 2, 2),
#  (102, 2, 2),
#  (103, 2, 2),
#  (104, 2, 2),
#  (105, 2, 2),
#  (106, 84, 2),
#  (114, 2, 2),
#  (115, 2, 2),
#  (116, 2, 2),
#  (117, 6, 2),
#  (118, 4, 2),
#  (119, 2, 2),
#  (121, 4, 2),
#  (128, 2, 2),
#  (129, 2, 2),
# ...

# %%
cursor.execute(" select  col1,count(*),col11 from students.glassdata order by col6 ")

# %%
cursor.fetchall()
# Out:
# [(6, 427, 1)]

# %%
cursor.execute("select count(col1),col2 from students.glassdata group by col1")

# %%
cursor.execute("select count(col1)  from students.glassdata group by col1 ")

# %%
cursor.fetchall()
# Out:
# [(5, 8.0),
#  (2, 1.51761),
#  (2, 1.51618),
#  (2, 1.51742),
#  (2, 1.51743),
#  (2, 1.51756),
#  (2, 1.51918),
#  (2, 1.51755),
#  (2, 1.51571),
#  (2, 1.51763),
#  (2, 1.51589),
#  (2, 1.51748),
#  (2, 1.51763),
#  (2, 1.51761),
#  (2, 1.51784),
#  (2, 1.52196),
#  (2, 1.51911),
#  (2, 1.51735),
#  (2, 1.5175),
#  (2, 1.51966),
#  (2, 1.51736),
#  (2, 1.51751),
#  (2, 1.5172),
#  (2, 1.51764),
#  (2, 1.51793),
#  (2, 1.51721),
#  (2, 1.51768),
#  (2, 1.51784),
#  (2, 1.51768),
#  (2, 1.51747),
#  (2, 1.51775),
#  (2, 1.51753),
#  (2, 1.51783),
#  (2, 1.51567),
#  (2, 1.51909),
#  (2, 1.51797),
#  (2, 1.52213),
#  (2, 1.52213),
#  (2, 1.51793),
#  (2, 1.51755),
#  (2, 1.51779),
#  (2, 1.5221),
#  (2, 1.51786),
#  (2, 1.519),
#  (2, 1.51869),
#  (2, 1.52667),
#  (2, 1.52223),
#  (2, 1.51898),
#  (2, 1.5232),
#  (2, 1.51926),
#  (2, 1.51808),
#  (2, 1.51837),
#  (2, 1.51778),
#  (2, 1.51769),
#  (2, 1.51215),
#  (2, 1.51824),
#  (2, 1.51754),
#  (2, 1.51754),
#  (2, 1.51905),
# ...

# %%
cursor.execute("select count(col1),col2 from students.glassdata group by col1")

# %%
cursor.fetchall()
# Out:
# [(5, 8.0),
#  (2, 1.51761),
#  (2, 1.51618),
#  (2, 1.51742),
#  (2, 1.51743),
#  (2, 1.51756),
#  (2, 1.51918),
#  (2, 1.51755),
#  (2, 1.51571),
#  (2, 1.51763),
#  (2, 1.51589),
#  (2, 1.51748),
#  (2, 1.51763),
#  (2, 1.51761),
#  (2, 1.51784),
#  (2, 1.52196),
#  (2, 1.51911),
#  (2, 1.51735),
#  (2, 1.5175),
#  (2, 1.51966),
#  (2, 1.51736),
#  (2, 1.51751),
#  (2, 1.5172),
#  (2, 1.51764),
#  (2, 1.51793),
#  (2, 1.51721),
#  (2, 1.51768),
#  (2, 1.51784),
#  (2, 1.51768),
#  (2, 1.51747),
#  (2, 1.51775),
#  (2, 1.51753),
#  (2, 1.51783),
#  (2, 1.51567),
#  (2, 1.51909),
#  (2, 1.51797),
#  (2, 1.52213),
#  (2, 1.52213),
#  (2, 1.51793),
#  (2, 1.51755),
#  (2, 1.51779),
#  (2, 1.5221),
#  (2, 1.51786),
#  (2, 1.519),
#  (2, 1.51869),
#  (2, 1.52667),
#  (2, 1.52223),
#  (2, 1.51898),
#  (2, 1.5232),
#  (2, 1.51926),
#  (2, 1.51808),
#  (2, 1.51837),
#  (2, 1.51778),
#  (2, 1.51769),
#  (2, 1.51215),
#  (2, 1.51824),
#  (2, 1.51754),
#  (2, 1.51754),
#  (2, 1.51905),
# ...

# %%
cursor.execute("select col1,count(col1),col11,count(col11) from students.glassdata group by col1 order by col1")

# %%
cursor.fetchall()
# Out:
# [(2, 2, 1, 2),
#  (3, 2, 1, 2),
#  (5, 2, 1, 2),
#  (6, 5, 1, 5),
#  (7, 2, 1, 2),
#  (8, 2, 1, 2),
#  (9, 2, 1, 2),
#  (10, 2, 1, 2),
#  (11, 2, 1, 2),
#  (12, 2, 1, 2),
#  (13, 2, 1, 2),
#  (14, 2, 1, 2),
#  (15, 2, 1, 2),
#  (16, 2, 1, 2),
#  (17, 2, 1, 2),
#  (18, 2, 1, 2),
#  (19, 2, 1, 2),
#  (20, 2, 1, 2),
#  (21, 2, 1, 2),
#  (22, 2, 1, 2),
#  (23, 2, 1, 2),
#  (24, 2, 1, 2),
#  (25, 2, 1, 2),
#  (26, 2, 1, 2),
#  (27, 2, 1, 2),
#  (28, 2, 1, 2),
#  (29, 2, 1, 2),
#  (30, 2, 1, 2),
#  (31, 2, 1, 2),
#  (32, 2, 1, 2),
#  (33, 2, 1, 2),
#  (34, 2, 1, 2),
#  (35, 2, 1, 2),
#  (36, 2, 1, 2),
#  (37, 2, 1, 2),
#  (38, 2, 1, 2),
#  (39, 2, 1, 2),
#  (40, 2, 1, 2),
#  (41, 2, 1, 2),
#  (42, 2, 1, 2),
#  (43, 2, 1, 2),
#  (44, 2, 1, 2),
#  (45, 2, 1, 2),
#  (46, 2, 1, 2),
#  (47, 2, 1, 2),
#  (48, 2, 1, 2),
#  (49, 2, 1, 2),
#  (50, 2, 1, 2),
#  (51, 2, 1, 2),
#  (52, 2, 1, 2),
#  (53, 2, 1, 2),
#  (54, 2, 1, 2),
#  (55, 2, 1, 2),
#  (56, 2, 1, 2),
#  (57, 2, 1, 2),
# ...

# %%
cursor.execute("select *from students.glassdata  ")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
cursor.execute("select *from students.ineuron")

# %%
cursor.fetchall()
# Out:
# [(423, 'Saurabh', 'Chaudhari', 1223231, 'FSDS'),
#  (424, 'Himanshu', 'Salvekar', 1223232, 'FSDS 2.0'),
#  (425, 'Danny', 'Bright', 1223233, 'FSDS 2.0'),
#  (426, 'Devashish', 'Salvekar', 1223234, 'FSDS 2.0')]

# %%
cursor.execute("select count(*),classname from students.ineuron where classname='FSDS 2.0'")

# %%
cursor.fetchall()
# Out:
# [(3, 'FSDS 2.0')]

# %%
cursor.execute("select count(*),classname from students.ineuron group by classname")

# %%
cursor.fetchall()
# Out:
# [(1, 'FSDS'), (3, 'FSDS 2.0')]

# %%
cursor.execute("drop table students.ineuron")

# %%
#QueriesCovered
'''
create database
create table
delete table
delete record
insert
update 
groupby
where

'''

# %%
cursor.execute("select *from students.glassdata")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
cursor.execute("select col1,col2,col11 from students.glassdata where col1=11 or col11=2")

# %%
cursor.fetchall()
# Out:
# [(11, 1.51571, 1),
#  (71, 1.51574, 2),
#  (72, 1.51848, 2),
#  (73, 1.51593, 2),
#  (74, 1.51631, 2),
#  (75, 1.51596, 2),
#  (76, 1.5159, 2),
#  (77, 1.51645, 2),
#  (78, 1.51627, 2),
#  (79, 1.51613, 2),
#  (80, 1.5159, 2),
#  (81, 1.51592, 2),
#  (82, 1.51593, 2),
#  (83, 1.51646, 2),
#  (84, 1.51594, 2),
#  (85, 1.51409, 2),
#  (86, 1.51625, 2),
#  (87, 1.51569, 2),
#  (88, 1.51645, 2),
#  (89, 1.51618, 2),
#  (90, 1.5164, 2),
#  (91, 1.51841, 2),
#  (92, 1.51605, 2),
#  (93, 1.51588, 2),
#  (94, 1.5159, 2),
#  (95, 1.51629, 2),
#  (96, 1.5186, 2),
#  (97, 1.51841, 2),
#  (98, 1.51743, 2),
#  (99, 1.51689, 2),
#  (100, 1.51811, 2),
#  (101, 1.51655, 2),
#  (102, 1.5173, 2),
#  (103, 1.5182, 2),
#  (104, 1.52725, 2),
#  (105, 1.5241, 2),
#  (106, 1.52475, 2),
#  (107, 1.53125, 2),
#  (108, 1.53393, 2),
#  (109, 1.52222, 2),
#  (110, 1.51818, 2),
#  (111, 1.52664, 2),
#  (112, 1.52739, 2),
#  (113, 1.52777, 2),
#  (114, 1.51892, 2),
#  (115, 1.51847, 2),
#  (116, 1.51846, 2),
# ...

# %%
#%anything
cursor.execute("select * from students.glassdata where col2 LIKE '1.51%'")
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-71-3cf81d219ba5> in <module>
#       1 #%anything
# ----> 2 cursor.execute("select * from students.glassdata where col2 LIKE '1.51%'")
#
# ~\anaconda\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     250         except (ProgrammingError, ReferenceError) as err:
#     251             raise ProgrammingError("Cursor is not connected", 2055) from err
# --> 252         self._cnx.handle_unread_result()
#     253
#     254         stmt = ""
#
# ~\anaconda\lib\site-packages\mysql\connector\connection_cext.py in handle_unread_result(self, prepared)
#     870             self.consume_results()
#     871         elif unread_result:
# --> 872             raise InternalError("Unread result found")
#     873
# ...

# %%
cursor.fetchall()
# Out:
# [(2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("select *from students.glassdata")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
#ordering the dataset by ascending order of col2
cursor.execute("select *from students.glassdata order by col2")

# %%
cursor.fetchall()
# Out:
# [(185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (57, 1.51215, 12.99, 3.47, 1.12, 72.98, 0.62, 8.35, 0.0, 0.31, 1),
#  (57, 1.51215, 12.99, 3.47, 1.12, 72.98, 0.62, 8.35, 0.0, 0.31, 1),
#  (181, 1.51299, 14.4, 1.74, 1.54, 74.55, 0.0, 7.59, 0.0, 0.0, 6),
#  (181, 1.51299, 14.4, 1.74, 1.54, 74.55, 0.0, 7.59, 0.0, 0.0, 6),
#  (172, 1.51316, 13.02, 0.0, 3.04, 70.48, 6.21, 6.96, 0.0, 0.0, 5),
#  (172, 1.51316, 13.02, 0.0, 3.04, 70.48, 6.21, 6.96, 0.0, 0.0, 5),
#  (173, 1.51321, 13.0, 0.0, 3.02, 70.7, 6.21, 6.93, 0.0, 0.0, 5),
#  (173, 1.51321, 13.0, 0.0, 3.02, 70.7, 6.21, 6.93, 0.0, 0.0, 5),
#  (85, 1.51409, 14.25, 3.09, 2.08, 72.28, 1.1, 7.08, 0.0, 0.0, 2),
#  (85, 1.51409, 14.25, 3.09, 2.08, 72.28, 1.1, 7.08, 0.0, 0.0, 2),
# ...

# %%
cursor.execute("select *from (select *from students.glassdata where col1 > 112) as a where col11=3")

# %%
cursor.fetchall()
# Out:
# [(147, 1.51769, 13.65, 3.66, 1.11, 72.77, 0.11, 8.6, 0.0, 0.0, 3),
#  (148, 1.5161, 13.33, 3.53, 1.34, 72.67, 0.56, 8.33, 0.0, 0.0, 3),
#  (149, 1.5167, 13.24, 3.57, 1.38, 72.7, 0.56, 8.44, 0.0, 0.1, 3),
#  (150, 1.51643, 12.16, 3.52, 1.35, 72.89, 0.57, 8.53, 0.0, 0.0, 3),
#  (151, 1.51665, 13.14, 3.45, 1.76, 72.48, 0.6, 8.38, 0.0, 0.17, 3),
#  (152, 1.52127, 14.32, 3.9, 0.83, 71.5, 0.0, 9.49, 0.0, 0.0, 3),
#  (153, 1.51779, 13.64, 3.65, 0.65, 73.0, 0.06, 8.93, 0.0, 0.0, 3),
#  (154, 1.5161, 13.42, 3.4, 1.22, 72.69, 0.59, 8.32, 0.0, 0.0, 3),
#  (155, 1.51694, 12.86, 3.58, 1.31, 72.61, 0.61, 8.79, 0.0, 0.0, 3),
#  (156, 1.51646, 13.04, 3.4, 1.26, 73.01, 0.52, 8.58, 0.0, 0.0, 3),
#  (157, 1.51655, 13.41, 3.39, 1.28, 72.64, 0.52, 8.65, 0.0, 0.0, 3),
#  (158, 1.52121, 14.03, 3.76, 0.58, 71.79, 0.11, 9.65, 0.0, 0.0, 3),
#  (159, 1.51776, 13.53, 3.41, 1.52, 72.04, 0.58, 8.79, 0.0, 0.0, 3),
#  (160, 1.51796, 13.5, 3.36, 1.63, 71.94, 0.57, 8.81, 0.0, 0.09, 3),
# ...

# %%
cursor.execute("select *from students.glassdata group by col1 having count(col1)>4")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1)]

# %%
cursor.execute("select *from students.glassdata where col1=6")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1)]
