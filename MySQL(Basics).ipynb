# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as conn

# %%
mydb=conn.connect(host='localhost',user='root',passwd='himanshu@123')

# %%
mydb

# %%
cursor=mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('students',),
#  ('sys',),
#  ('world',)]

# %%
cursor=mydb.cursor()

# %%
cursor.execute('create database students')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     564                 query = query.encode("utf-8")
# --> 565             self._cmysql.query(
#     566                 query,
#
# MySQLInterfaceError: Can't create database 'students'; database exists
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-26-13eb977e8e32> in <module>
# ----> 1 cursor.execute('create database students')
#
# ~\anaconda\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     277
#     278         try:
# --> 279             result = self._cnx.cmd_query(
#     280                 stmt,
# ...

# %%
cursor.execute("create table students.ineuron(studentid INT(10),firstname VARCHAR(30) ,lastname VARCHAR(30), regid INT(10),classname VARCHAR(30))")

# %%
cursor.execute('use students')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('ineuron',)]

# %%
cursor.execute("insert into students.ineuron values(423,'Saurabh','Chaudhari',1223231,'FSDS')")

# %%
mydb.commit()

# %%
cursor.execute("select *from students.ineuron")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e45de115a52f> in <module>
# ----> 1 cursor.execute("select *from students.ineuron")
#
# NameError: name 'cursor' is not defined

# %%
cursor.fetchall()
# Out:
# [(423, 'Saurabh', 'Chaudhari', 1223231, 'FSDS'),
#  (424, 'Himanshu', 'Salvekar', 1223232, 'FSDS 2.0'),
#  (425, 'Danny', 'Bright', 1223233, 'FSDS 2.0'),
#  (426, 'Devashish', 'Salvekar', 1223234, 'FSDS 2.0')]

# %%
cursor.execute("insert into students.ineuron values(426,'Devashish','Salvekar',1223234,'FSDS 2.0')")

# %%
cursor.execute("create table students.glassdata(col1 INT(10),col2 float(10,5) ,col3 float(10,5) ,col4 float(10,5) ,col5 float(10,5) ,col6 float(10,5) ,col7 float(10,5) ,col8 float(10,5) ,col9 float(10,5) ,col10 float(10,5) ,col11 INT(10))")

# %%
cursor.execute("use students")
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('glassdata',), ('ineuron',)]

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is DA70-7AC6
#
#  Directory of C:\Users\devas\Desktop\sample_project_1
#
# 06-01-2023  17:00    <DIR>          .
# 06-01-2023  01:31    <DIR>          ..
# 06-01-2023  00:41    <DIR>          .ipynb_checkpoints
# 26-12-2022  14:14    <DIR>          __pycache__
# 13-07-2022  22:52               369 car-sales.csv
# 15-07-2022  17:48               287 car-sales-missing-data.csv
# 12-07-2022  19:20    <DIR>          env
# 27-12-2022  17:29            35,671 Exceptional_handling+.ipynb
# 27-12-2022  18:00                21 functions task
# 02-11-2022  11:39             1,763 functions task.txt
# 06-01-2023  16:35            11,903 glass (1).data
# 13-07-2022  22:02            11,328 heart-disease.csv
# 07-12-2022  22:37           153,578 HimanshuSalvekar_Resume_PDF.pdf
# 01-12-2022  22:40             5,952 INeu-Assn-4.0.ipynb
# 03-01-2023  19:33             9,134 Ineuron_Python_Basic_Assn_4.ipynb
# ...

# %%
file=open("glass (1).data",'r')

# %%
file.read()
# Out:
# '1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1\n2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1\n3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1\n4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1\n5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1\n6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1\n7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1\n8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1\n9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1\n10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1\n11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1\n12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1\n13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1\n14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1\n15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1\n16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1\n17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1\n18,1.52196,14.36,3.85,0.89,71.36,0.15,9.15,0.00,0.00,1
# ...

# %%
import csv

with open("glass (1).data",'r') as f:
    glass_data=csv.reader(f,delimiter='\n')
    for i in glass_data:
        print(i[0])
# Out:
# 1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1
# 2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1
# 3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1
# 4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1
# 5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1
# 6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1
# 7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1
# 8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1
# 9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1
# 10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1
# 11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1
# 12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1
# 13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1
# 14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1
# 15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1
# 16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1
# 17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1
# ...

# %%
cursor.execute("insert into students.glassdata values(1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1)")

# %%
mydb.commit()

# %%
cursor.execute("select *from students.glassdata")

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
# ...

# %%
with open('glass (1).data','r') as f:
    glass_data=csv.reader(f,delimiter='\n')
    for i in glass_data:
        print(i)
        print(f'insert into glassdata values ({str(i[0])})')
        cursor.execute(f"insert into students.glassdata values ({str(i[0])})")
mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3a8ea749df16> in <module>
#       1 with open('glass (1).data','r') as f:
# ----> 2     glass_data=csv.reader(f,delimiter='\n')
#       3     for i in glass_data:
#       4         print(type(i))
#       5         print(f'insert into glassdata values ({str(i[0])})')
#
# NameError: name 'csv' is not defined

# %%
import pandas as pd

# %%
pd.read_sql("select *from students.glassdata",mydb)
# Out:
#      col1     col2   col3  col4  col5   col6  col7  col8  col9  col10  col11
# 0       1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00    0.0      1
# 1       1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00    0.0      1
# 2       2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.0      1
# 3       3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.0      1
# 4       4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.0      1
# ..    ...      ...    ...   ...   ...    ...   ...   ...   ...    ...    ...
# 424   210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.0      7
# 425   211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.0      7
# 426   212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.0      7
# 427   213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.0      7
# 428   214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.0      7
#
# [429 rows x 11 columns]

# %%
pd.read_sql("show databases",mydb)
# Out:
#              Database
# 0  information_schema
# 1               mysql
# 2  performance_schema
# 3              sakila
# 4            students
# 5                 sys
# 6               world
